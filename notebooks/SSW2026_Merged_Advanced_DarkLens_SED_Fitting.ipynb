# %% [markdown]
# # SSW2026 Advanced Dark-Lens + SED-Fitting Project
#
# This Azure-compatible notebook merges the official SED-fitting workflow with the advanced dark-lens analysis.
#
# The full working notebook is also available in the downloadable repository package generated in ChatGPT.

# %%
from pathlib import Path

PROJECT_DIR = Path('/workspace')
DATA_DIR = PROJECT_DIR / 'data'
ISO_DIR = PROJECT_DIR / 'isochrones'
OUTPUT_DIR = PROJECT_DIR / 'outputs'
EXECUTED_DIR = PROJECT_DIR / 'executed'

for directory in [DATA_DIR, ISO_DIR, OUTPUT_DIR, EXECUTED_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print('Project directory:', PROJECT_DIR)
print('Data directory:', DATA_DIR)
print('Isochrone directory:', ISO_DIR)
print('Output directory:', OUTPUT_DIR)

# %% [markdown]
# ## Pipeline execution
#
# The Azure DevOps pipeline validates SPISEA, checks the Roman filter data, validates the workshop Parquet files, generates the persistent isochrone grid, and executes this notebook with `nbconvert`.
